# %% [markdown]
# # [goulib](../notebook.ipynb).stats
# very basic statistics functions

# %%
from goulib.notebook import *
from goulib.stats import *

# %% [markdown]
# ## Discrete distributions

# %%
dice=Discrete(range(1,6+1))
dice
# Out:
# Discrete(mean=3.5, var=3.5)

# %%
Y=Discrete({1:0.2, -1:0.8})
Y
# Out:
# Discrete(mean=-0.6, var=2)

# %%
X=Discrete({-2:0.15,-1:.2,0:.3,1:.2,2:.15})
X**2+Y
# Out:
# Stats(mean=-0.3, var=8.640625)

# %% [markdown]
# ## Normal distribution

# %%
n1=Normal()
print(n1)
n1
# Out:
# Normal(mean=0, var=1)
# Tuple([Call(Name('normal_pdf', Load()), [Name('x', Load()), Name('mean', Load()), Name('sigma', Load())], []), Name('data', Load())], Load())

# %%
n2=Normal([],4,4)
n2
# Out:
# Tuple([Call(Name('normal_pdf', Load()), [Name('x', Load()), Name('mean', Load()), Name('sigma', Load())], []), Name('data', Load())], Load())

# %%
n1+n2
# Out:
# Tuple([Call(Name('normal_pdf', Load()), [Name('x', Load()), Name('mean', Load()), Name('sigma', Load())], []), Name('data', Load())], Load())

# %%
plot.plot([n1,n2,n1+n2])
