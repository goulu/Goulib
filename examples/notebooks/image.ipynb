# %% [markdown]
# # [goulib](../notebook.ipynb).image
# image processing made easy
#
# Combines flexibility of [PIL Python Imaging Library (Pillow)](https://pypi.python.org/pypi/Pillow/) with the power of [scikit-image](http://scikit-image.org/) embedded in an easy to use Image class

# %%
from goulib.notebook import *
from goulib.image import *

import PIL.Image as PILImage

# %%
lena_original=Image('../tests/data/lena.png') #Image can be init'ed from a path

# %%
from skimage import data
camera_original=Image(data.camera()) #or from an array

# %%
# Image has many "PIL compatible" methods, but they always return a result Image
# instead of working in-place :
size=(128,128)
lena=lena_original.resize(size)
lena_gray=lena.grayscale()
camera=camera_original.resize(size,PILImage.LANCZOS)

# %% [markdown]
# ## Rendering

# %%
lena #images have a default HTML representation
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %%
from goulib.table import Table # images can also be put in tables ! and they're responsive !
Table([[lena,lena_gray,camera],['lena','lena gray','camera']])
# Out:
# <class 'goulib.table.Table'>(len=2,titles=[],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=L shape=(128, 128, 1) type=uint8)], ['lena', 'lena gray', 'camera']])

# %% [markdown]
# ## Image modes and Conversions

# %%
#Images have an attached immutable "mode" string:
h(str(lena)) #usually RGB(A) (float) for color images
h(str(lena_gray)) #gray images can be either F (float) or L (int)
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)
# Image(mode=F shape=(128, 128, 1) type=float64)

# %%
h(modes) #supported modes are those from scipy + those from PIL (but in float instead of uint)
# Out:
# {1:Mode('bool',1x<class 'numpy.uint8'>,[0-1],
# F:Mode('gray',1x<class 'float'>,[0-1],
# U:Mode('gray',1x<class 'numpy.uint16'>,[0-65535],
# I:Mode('gray',1x<class 'numpy.int16'>,[-32768-32767],
# L:Mode('gray',1x<class 'numpy.uint8'>,[0-255],
# P:Mode('ind',1x<class 'numpy.uint16'>,[0-65535],
# RGB:Mode('rgb',3x<class 'float'>,[0-1],
# RGBA:Mode('rgba',4x<class 'float'>,[0-1],
# CMYK:Mode('cmyk',4x<class 'float'>,[0-1],
# LAB:Mode('lab',3x<class 'float'>,[-1-1],
# XYZ:Mode('xyz',3x<class 'float'>,[0-1],
# HSV:Mode('hsv',3x<class 'float'>,[0-1]}

# %%
converters.edges() #a graph between modes
# Out:
# OutMultiEdgeDataView([('bool', 'gray'), ('bool', 'rgb'), ('gray', 'bool'), ('gray', 'rgb'), ('rgb', 'gray'), ('rgb', 'rgba'), ('rgb', 'cmyk'), ('rgb', 'lab'), ('rgb', 'xyz'), ('rgb', 'hsv'), ('ind', 'rgb'), ('rgba', 'rgb'), ('cmyk', 'rgb'), ('lab', 'ind'), ('lab', 'rgb'), ('lab', 'xyz'), ('xyz', 'rgb'), ('xyz', 'lab'), ('hsv', 'rgb')])

# %%
#conversions from/to any mode are implemented by traversing the graph automagically
lena_conv=dict((mode, lena.convert(mode)) for mode in modes)
lena_conv['1']*=255 # multiply 0/1 image so we can see it
Table([[lena_conv[m],m] for m in sorted(lena_conv)]).transpose()
# Out:
# <class 'goulib.table.Table'>(len=1,titles=[Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=CMYK shape=(128, 128, 4) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=HSV shape=(128, 128, 3) type=float64), Image(mode=I shape=(128, 128, 1) type=int16), Image(mode=L shape=(128, 128, 1) type=uint8), Image(mode=LAB shape=(128, 128, 3) type=float64), Image(mode=P shape=(128, 128, 1) type=uint16), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGBA shape=(128, 128, 4) type=float64), Image(mode=U shape=(128, 128, 1) type=uint16), Image(mode=XYZ shape=(128, 128, 3) type=float64)],data=[['1', 'CMYK', 'F', 'HSV', 'I', 'L', 'LAB', 'P', 'RGB', 'RGBA', 'U', 'XYZ']])

# %% [markdown]
# note that displaying multi channel images assumes RGB(A) images, so for the above images we have:
# - LAB : L=Red, A=Green, B=Blue (low)
# - HSV : H=Red, S=Green, V=Blue
# - CMYK: C=RED (almost zero), M=Green, Y=Blue, K=Alpha transparency (hence the image is low contrast)

# %% [markdown]
# ## Color / Planes separation and reconstruction

# %%
lena_rgb=lena.split() #extract gray level images from each channel
images=[lena,lena_gray]+lena_rgb
Table([images],titles=['Lena','Gray']+[c for c in lena.mode])
# Out:
# <class 'goulib.table.Table'>(len=1,titles=['Lena', 'Gray', 'R', 'G', 'B'],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=F shape=(128, 128, 1) type=float64)]])

# %%
camera=camera.convert('F') #not all conversions are automatic yet ...
Image(lena_rgb+[-camera]) # merges color planes and use camera as alpha channel
# Out:
# Image(mode=RGBA shape=(128, 128, 4) type=float64)

# %%
lena_lab=lena_conv['LAB'].split() #extract gray level images from each channel
images=[lena]+lena_lab
Table([images],titles=['Lena']+[c for c in lena_conv['LAB'].mode])
# Out:
# <class 'goulib.table.Table'>(len=1,titles=['Lena', 'L', 'A', 'B'],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=F shape=(128, 128, 1) type=float64)]])

# %%
Image(lena_lab,'LAB').convert('RGB')
lena_conv['LAB'].convert('RGB')
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %%
lena_gray*'cyan' #gray colors can be multiplied by a color to make a colorized image
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %%
lena_gray.colorize('blue','yellow') #colorize between specified black and white colors
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %%
colors=['Cyan','Magenta','Yellow','blacK']
cmyk=lena.split('CMYK') # converts from RGB to CMYK under the hood
cmyk2=[im.colorize(col) for im,col in zip(cmyk,colors)] 
Table([cmyk,cmyk2],titles=colors)
# Out:
# <class 'goulib.table.Table'>(len=2,titles=['Cyan', 'Magenta', 'Yellow', 'blacK'],data=[[Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=F shape=(128, 128, 1) type=float64), Image(mode=F shape=(128, 128, 1) type=float64)], [Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)]])

# %%
#rebuild color image from colorized CMYK planes
cmyk2[0]-(-cmyk2[1])-(-cmyk2[2])-(-cmyk2[3]) #what a strange syntax ...
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %% [markdown]
# ## Palette and colors reduction
#
# optimal palette is computed automatically in Lab space from a k-means segmentation of a radom subset of pixels (see http://scikit-learn.org/stable/auto_examples/cluster/plot_color_quantization.html )

# %%
lenaP=lena.convert('P',colors=5) #image can be reduced to any number of colors
h(lenaP,lenaP.palette) # the optimal palette is computed automatically
# Out:
# <img src="data:image/png;base64,..."> <div style="display:flex; width:100%;"><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#d9a294; color:#d9a294;" title="[0] ~darksalmon (D65)
# lab = 71.451, 18.463, 15.279
# rgb = 0.852, 0.636, 0.581
# hex = #d9a294">&nbsp;</div><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#7f4a7c; color:#7f4a7c;" title="[1] ~darkmagenta (D65)
# lab = 39.258, 30.493, -18.891
# rgb = 0.496, 0.290, 0.485
# hex = #7f4a7c">&nbsp;</div><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#d77067; color:#d77067;" title="[2] ~indianred (D65)
# lab = 58.954, 39.786, 23.586
# rgb = 0.845, 0.437, 0.403
# hex = #d77067">&nbsp;</div><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#a34351; color:#a34351;" title="[3] ~brown (D65)
# lab = 41.773, 41.153, 11.691
# rgb = 0.639, 0.261, 0.319
# hex = #a34351">&nbsp;</div><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#601a41; color:#601a41;" title="[4] ~purple (D65)
# lab = 22.298, 35.369, -7.341
# rgb = 0.375, 0.102, 0.255
# hex = #601a41">&nbsp;</div></div>

# %%
#palette can also be explicitely specified
from goulib.colors import Palette
palette=Palette(['purple','peachpuff','indianred','brown','lightcoral'])
lenaP=lena.convert('P',colors=palette)
h(lenaP,lenaP.palette)
# Out:
# <img src="data:image/png;base64,..."> <div style="display:flex; width:100%;"><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#800080; color:#800080;" title="[0] purple (D65)
# hex = #800080
# rgb = 0.502, 0, 0.502
# lab = 29.784, 58.927, -36.485">&nbsp;</div><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#ffdab9; color:#ffdab9;" title="[1] peachpuff (D65)
# hex = #ffdab9
# rgb = 1, 0.855, 0.725
# lab = 89.350, 8.083, 21.026">&nbsp;</div><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#cd5c5c; color:#cd5c5c;" title="[2] indianred (D65)
# hex = #cd5c5c
# rgb = 0.804, 0.361, 0.361
# lab = 53.395, 44.828, 22.119">&nbsp;</div><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#a52a2a; color:#a52a2a;" title="[3] brown (D65)
# hex = #a52a2a
# rgb = 0.647, 0.165, 0.165
# lab = 37.526, 49.690, 30.544">&nbsp;</div><div style="display:flex-block; min-width: 1px;  flex-basis: 90%; background:#f08080; color:#f08080;" title="[4] lightcoral (D65)
# hex = #f08080
# rgb = 0.941, 0.502, 0.502
# lab = 66.157, 42.809, 19.559">&nbsp;</div></div>

# %% [markdown]
# ## Dithering

# %%
Table([[lena.dither(method,n) for method in dithering] for n in (2,3,4)], titles=dithering.values())
# Out:
# <class 'goulib.table.Table'>(len=3,titles=dict_values([nearest, random, floyd-steinberg, philips, sierra lite, stucki, Jarvis, Judice, and Ninke, Atkinson, Burkes]),data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)], [Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)], [Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)]])

# %%
lena_dither=lena.dither() # applies automatically to RGB planes
h(lena_dither,'1 bit dithering')
# Out:
# <img src="data:image/png;base64,..."> 1 bit dithering

# %%
h(lena.dither(n=4),'2 bit dithering')
# Out:
# <img src="data:image/png;base64,..."> 2 bit dithering

# %% [markdown]
# ## Geometric Transforms

# %%
lena_fx=lena.flip()
lena_fy=lena.flip(False,True)
h(lena_fx,lena_fy)
# Out:
# <img src="data:image/png;base64,..."> <img src="data:image/png;base64,...">

# %%
lena_180=lena.rotate(180)
lena_90=lena.rotate(90)
lena_90
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %% [markdown]
# Rotated image is perfect for multiples of 90 degrees, but for other values we must care of the missing pixels somehow

# %%
Table([[lena.rotate(-45,mode=m) for m in ['constant', 'edge', 'symmetric', 'reflect', 'wrap']]])
# Out:
# <class 'goulib.table.Table'>(len=1,titles=[],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)]])

# %%
lena_10=lena.rotate(10) # mode ='edge' by default
lena_10
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %% [markdown]
# ## Hash and Distances
#
# Two methods to hash images ( Average_hash and Perceptual_hash [described here](http://www.hackerfactor.com/blog/index.php?/archives/432-Looks-Like-It.html) are implemented)

# %%
h(hex(hash(lena))) # uses average_hash by default
h(hex(lena.perceptual_hash())) # both hash methods return 64 bits integer by default
h(hex(lena.perceptual_hash(4)), hex(lena.perceptual_hash(12))) # but shorter or larger hashes can be obtained
# Out:
# 0x169c3d890b0b8f93
# 0x99c6562d7533a296
# 0x9cd2 0x990c6f56d2da754335a6996668aaba4b36a8

# %% [markdown]
# "distances" between images can be easily calculated from the proportion of different bits in both hashes
#
# note that a distance of 1 means "totally different" while a distance of 2 means "inverted"

# %%
images=[lena,lena_dither,lena_gray,-lena,lena_10, camera]
adist=["average dist"]+[im.dist(lena,Image.average_hash) for im in images[1:]]
pdist=["perceptual dist"]+[im.dist(lena,Image.perceptual_hash) for im in images[1:]]
Table([images,adist,pdist],titles=['Lena','Dither','Gray','Negative','Rotate','Camera',])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-ccdb6bf041c6> in <module>
#       1 images=[lena,lena_dither,lena_gray,-lena,lena_10, camera]
# ----> 2 adist=["average dist"]+[im.dist(lena,Image.average_hash) for im in images[1:]]
#       3 pdist=["perceptual dist"]+[im.dist(lena,Image.perceptual_hash) for im in images[1:]]
#       4 Table([images,adist,pdist],titles=['Lena','Dither','Gray','Negative','Rotate','Camera',])
#
# <ipython-input-29-ccdb6bf041c6> in <listcomp>(.0)
#       1 images=[lena,lena_dither,lena_gray,-lena,lena_10, camera]
# ----> 2 adist=["average dist"]+[im.dist(lena,Image.average_hash) for im in images[1:]]
#       3 pdist=["perceptual dist"]+[im.dist(lena,Image.perceptual_hash) for im in images[1:]]
#       4 Table([images,adist,pdist],titles=['Lena','Dither','Gray','Negative','Rotate','Camera',])
#
# c:\dev\python\goulib\goulib\image.py in dist(self, other, method, hash_size, symmetries)
#     650             return [im.average_hash, im.perceptual_hash][method](hash_size)
#     651
# --> 652         h1 = h(self)
#     653
#     654         def diff(im):
#
# c:\dev\python\goulib\goulib\image.py in h(im)
#     648         """
#     649         def h(im):
# --> 650             return [im.average_hash, im.perceptual_hash][method](hash_size)
#     651
#     652         h1 = h(self)
#
# TypeError: list indices must be integers or slices, not function

# %%
#Image.dist is independent of the image size or mode, but does not handle symmetries and rotations by default

images=[lena,lena_fx,lena_fy,lena_180,lena_90,lena_10]
dist=["dist"]+[im.dist(lena) for im in images[1:]]
Table([images,dist],titles=['Lena','Flip X','Flip Y','Rot 180°','Rot 90°','Rot 10°'])
# Out:
# <class 'goulib.table.Table'>(len=2,titles=['Lena', 'Flip X', 'Flip Y', 'Rot 180°', 'Rot 90°', 'Rot 10°'],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)], ['dist', 1.25, 0.75, 1.25, 1.1875, 0.34375]])

# %%
#However, Image.dist has an option to handle symmetries and rotations by 90°

images=[lena,lena_fx,lena_fy,lena_180,lena_90,lena_10]
dist=["dist"]+[im.dist(lena,symmetries=True) for im in images[1:]]
Table([images,dist],titles=['Lena','Flip X','Flip Y','Rot 180°','Rot 90°','Rot 10°'])
# Out:
# <class 'goulib.table.Table'>(len=2,titles=['Lena', 'Flip X', 'Flip Y', 'Rot 180°', 'Rot 90°', 'Rot 10°'],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)], ['dist', 0, 0, 0, 0, 0.34375]])

# %% [markdown]
# ## Canvas and geometric transformations

# %%
images=[
    lena.expand((150,150)),       # centered by default
    lena.expand((150,150),5,20),  # dx,dy offset
    lena.expand((150,150),-1,-5), # negative offsets wr to lower right
    lena.expand((150,150),None,0),#centered in X, offset in Y
    lena.expand((150,150),-1,None),#centered in Y, offset in X
    lena.expand((150,150),0,0).shift(3.25,2.5) #and we can do SUBPIXEL shifts !!!
]
Table([images])
# Out:
# <class 'goulib.table.Table'>(len=1,titles=[],data=[[Image(mode=RGB shape=(150, 150, 3) type=float64), Image(mode=RGB shape=(150, 150, 3) type=float64), Image(mode=RGB shape=(150, 150, 3) type=float64), Image(mode=RGB shape=(150, 150, 3) type=float64), Image(mode=RGB shape=(150, 150, 3) type=float64), Image(mode=RGB shape=(150, 150, 3) type=float64)]])

# %%
images=[
    lena.expand((130,130),1,1), # 1 pixel border
    lena.expand((129,129),0.5,0.5) #  half pixel border ... can you see the difference?
    ]
Table([images])
# Out:
# <class 'goulib.table.Table'>(len=1,titles=[],data=[[Image(mode=RGB shape=(130, 130, 3) type=float64), Image(mode=RGB shape=(129, 129, 3) type=float64)]])

# %% [markdown]
# ## Slices, composition

# %%
face=lena_original[246:374,225:353] # images can be sliced . Note the first coordinate is Y, then X
face
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %%
eye=face[3:35,-35:-3] # negative indexes are handy in some cases
eye.scale(4)
# Out:
# Image(mode=RGB shape=(128, 128, 3) type=float64)

# %%
left=lena_original[:,0:256]
right=lena_original[:,256:]
stitched=Image(size=(513,513),mode='RGB',color='white')
stitched.add(left,(0,0))
stitched.add(right.shift(1,0),(256,0))
stitched
# Out:
# Image(mode=RGB shape=(513, 513, 3) type=float64)

# %% [markdown]
# ## Image Creation

# %%
# Image can be created from standard Python lists and iterators
# colormaps can be used to generate color images
from matplotlib import cm
a=[[-x*x+y*y for x in range(128)] for y in range(128)]
a=normalize(a)
print(a.max())
im=Image(a)
Table([[im,Image(a,colormap=cm.nipy_spectral)]])
# Out:
# 254
# <class 'goulib.table.Table'>(len=1,titles=[],data=[[Image(mode=I shape=(128, 128, 1) type=int16), Image(mode=I shape=(128, 128, 1) type=int16)]])

# %%
mask=disk(64)
Table([[lena+mask,lena-mask,lena*mask]])
# Out:
# <class 'goulib.table.Table'>(len=1,titles=[],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGBA shape=(128, 128, 4) type=float64)]])

# %% [markdown]
# ## Filtering
# gray level filters are automatically applied to RGB color planes and results re-merged in a color image
#
# Filters can be:
# * those available in PIL
# * those in skimage
# * custom functions

# %%
from PIL.ImageFilter import *
pilfilters=[BLUR, CONTOUR, DETAIL, EDGE_ENHANCE, EDGE_ENHANCE_MORE, EMBOSS, FIND_EDGES, SMOOTH, SMOOTH_MORE, SHARPEN]
lena_filtered=[lena.filter(f) for f in pilfilters]
from goulib.itertools2 import reshape
Table(reshape(lena_filtered,(0,5))) # nice way to limit table width, isn't it ?
# Out:
# <class 'goulib.table.Table'>(len=2,titles=[],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)], [Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)]])

# %%
from skimage.filters import sobel, prewitt, scharr, roberts
#demo with all filters that need no extra parameter
skifilters=[ sobel, prewitt, scharr, roberts]
lena_filtered=[lena.filter(f) for f in skifilters]
Table(reshape(lena_filtered,(0,5)))
# Out:
# <class 'goulib.table.Table'>(len=1,titles=[],data=[[Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64), Image(mode=RGB shape=(128, 128, 3) type=float64)]])

# %%
R, G, B = 0, 1, 2

# select regions where red is less than 100
mask = lena_rgb[R].filter(lambda i: 0 if i < 100 else 255)

# process the green band
out = lena_rgb[G].filter(lambda i: i * 0.1)

# paste the processed band back, but only where red was < 100
lena_rgb[R].paste(out, None, mask)

# build a new multiband image
Image(lena_rgb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-d9af6acaba71> in <module>
#       2
#       3 # select regions where red is less than 100
# ----> 4 mask = lena_rgb[R].filter(lambda i: 0 if i < 100 else 255)
#       5
#       6 # process the green band
#
# c:\dev\python\goulib\goulib\image.py in _adapter(image, *args, **kwargs)
#     117             return Image(channels, 'RGB')
#     118         else:
# --> 119             return func(image, *args, **kwargs)
#     120
#     121     return _adapter
#
# c:\dev\python\goulib\goulib\image.py in filter(self, f)
#     746             pass
#     747         im = self.pil
# --> 748         im = im.filter(f)
#     749         return Image(im, mode=self.mode)
#     750
#
# C:\Anaconda3\lib\site-packages\PIL\Image.py in filter(self, filter)
#    1198
#    1199         if isinstance(filter, Callable):
# -> 1200             filter = filter()
#    1201         if not hasattr(filter, "filter"):
#    1202             raise TypeError(
#
# TypeError: <lambda>() missing 1 required positional argument: 'i'

# %% [markdown]
# ## Correlation

# %%
face.grayscale().correlation(eye.grayscale())
# Out:
# Image(mode=F shape=(159, 159, 1) type=float64)
