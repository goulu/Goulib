# %% [markdown]
# # [Goulib](../notebook.ipynb).graph
# efficient Euclidian Graphs for [NetworkX](http://networkx.github.io/) and related algorithms

# %%
from Goulib import notebook
import networkx as nx
from Goulib.graph import *

# %%
g=nx.gn_graph(20)
nx.draw_networkx(g)

# %%
draw_networkx(g, #improved version over nx.draw_networkx
labels=True, # by default they're off
)

# %%
geo=nx.geographical_threshold_graph(50,25)
geo # NetworkX Graphs do not render in Notebooks...

# %%
geo=GeoGraph(geo)
geo # GeoGraphs do !

# %%
# it's easy to make GeoGraphs look nice
def edge_color(data): # simply define a function that maps edge data to a color
    return plt.get_cmap('Blues')(data['length']/.25)       
geo.render(edge_color=edge_color, node_size=50) #this will set geo.render_args ...
geo #... so here we display them :-)

# %%
d=to_drawing(geo) # graphs can also be converted or added to a Goulib.Drawing
from Goulib.geom import Circle
c=Circle((0.5,0.5),0.5)
c.color='red'
d.append(c)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\users\guglie0p\develop\python\goulib\Goulib\graph.py in to_drawing(g, d, edges)
#     701         try:
# --> 702             e=data['entity']
#     703         except:
#
# KeyError: 'entity'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8b6d2c3d8cee> in <module>()
# ----> 1 d=to_drawing(geo) # graphs can also be converted or added to a Goulib.Drawing
#       2 from Goulib.geom import Circle
#       3 c=Circle((0.5,0.5),0.5)
#       4 c.color='red'
#       5 d.append(c)
#
# d:\users\guglie0p\develop\python\goulib\Goulib\graph.py in to_drawing(g, d, edges)
#     702             e=data['entity']
#     703         except:
# --> 704             e=geom.Segment2(u,v)
#     705         d.append(e)
#     706     return d
#
# d:\users\guglie0p\develop\python\goulib\Goulib\geom.py in __init__(self, *args)
#     770             self.v = Vector2(args[0].v)
#     771         else:
# --> 772             self.p = Point2(args[0])
#     773             if type(args[1]) is Vector2:
#     774                 self.v = Vector2(args[1])
#
# d:\users\guglie0p\develop\python\goulib\Goulib\geom.py in __init__(self, *args)
#     299         :param *args: x,y values
#     300         """
# --> 301         self.x,self.y=argPair(*args)
#     302
#     303     @property
#
# TypeError: 'NoneType' object is not iterable

# %%
nodes=points_on_sphere(120)
sphere=GeoGraph(nodes=nodes) #GeoGraphs can also be built from n-dim points only
sphere.render(edge_color=edge_color, node_size=50) #this will set geo.render_args ...
sphere

# %%
delauney_triangulation(geo) #creates a new GeoGraph from Delauney triangulation of a GeoGraph's nodes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-bd21df353cd3> in <module>()
# ----> 1 delauney_triangulation(geo) #creates a new GeoGraph from Delauney triangulation of a GeoGraph's nodes
#
# d:\users\guglie0p\develop\python\goulib\Goulib\graph.py in delauney_triangulation(nodes, qhull_options, incremental, **kwargs)
#     725     # http://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.Delaunay.html
#     726     points=numpy.array(nodes)
# --> 727     tri = scipy.spatial.Delaunay(points, qhull_options=qhull_options, incremental=incremental)
#     728     kwargs['multi']=False #to avoid duplicating triangle edges below
#     729     g=GeoGraph(tri,dimension=tri.ndim,**kwargs)
#
# scipy/spatial/qhull.pyx in scipy.spatial.qhull.Delaunay.__init__ (scipy\spatial\qhull.c:16293)()
#
# scipy/spatial/qhull.pyx in scipy.spatial.qhull._Qhull.__init__ (scipy\spatial\qhull.c:2873)()
#
# ValueError: Buffer has wrong number of dimensions (expected 2, got 1)
